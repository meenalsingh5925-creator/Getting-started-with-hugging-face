# %% [markdown]
# <a href="https://colab.research.google.com/github/meenalsingh5925-creator/Getting-started-with-hugging-face/blob/main/requirements_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile requirements.txt
# gradio>=4.0.0
# transformers
# torch
# Out:
# Writing requirements.txt
